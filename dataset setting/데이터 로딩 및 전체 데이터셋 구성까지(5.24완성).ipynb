# %% [markdown]
# # Data Loading

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# %%
## 코랩에서 실행할시
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b461c10b0dfe> in <module>
#       1 ## 코랩에서 실행할시
# ----> 2 from google.colab import drive
#       3 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
#불러올 파일의 경로를 filename 변수에 저장
buy2018_1 = '/content/drive/MyDrive/날씨 콘테스트/Data/buy2018_1.csv'
buy2018_2 = '/content/drive/MyDrive/날씨 콘테스트/Data/buy2018_2.csv'
buy2019_1 = '/content/drive/MyDrive/날씨 콘테스트/Data/buy2019_1.csv'
buy2019_2 = '/content/drive/MyDrive/날씨 콘테스트/Data/buy2019_2.csv'
sns2018_1 = '/content/drive/MyDrive/날씨 콘테스트/Data/sns2018_1.csv'
sns2018_2 = '/content/drive/MyDrive/날씨 콘테스트/Data/sns2018_2.csv'
sns2019_1 = '/content/drive/MyDrive/날씨 콘테스트/Data/sns2019_1.csv'
sns2019_2 = '/content/drive/MyDrive/날씨 콘테스트/Data/sns2019_2.csv'

# %%
# 데이터 로딩
buy_2018_1 = pd.read_csv(buy2018_1)
buy_2018_2 = pd.read_csv(buy2018_2)
buy_2019_1 = pd.read_csv(buy2019_1)
buy_2019_2 = pd.read_csv(buy2019_2)
sns_2018_1 = pd.read_csv(sns2018_1)
sns_2018_2 = pd.read_csv(sns2018_2)
sns_2019_1 = pd.read_csv(sns2019_1)
sns_2019_2 = pd.read_csv(sns2019_2)

# %%
## 개인 주피터에서 실행할 시
# 데이터 로딩
buy_2018_1 = pd.read_csv('./기업데이터/buy2018_1.csv')
buy_2018_2 = pd.read_csv('./기업데이터/buy2018_2.csv')
buy_2019_1 = pd.read_csv('./기업데이터/buy2019_1.csv')
buy_2019_2 = pd.read_csv('./기업데이터/buy2019_2.csv')
sns_2018_1 = pd.read_csv('./기업데이터/sns2018_1.csv')
sns_2018_2 = pd.read_csv('./기업데이터/sns2018_2.csv')
sns_2019_1 = pd.read_csv('./기업데이터/sns2019_1.csv')
sns_2019_2 = pd.read_csv('./기업데이터/sns2019_2.csv')

# %%
# 기존의 1부터 시작하는 이미 부여된 index 열 삭제
buy_2018_1 = buy_2018_1.drop('Unnamed: 0', axis=1)
buy_2018_2 = buy_2018_2.drop('Unnamed: 0', axis=1)
buy_2019_1 = buy_2019_1.drop('Unnamed: 0', axis=1)
buy_2019_2 = buy_2019_2.drop('Unnamed: 0', axis=1)
sns_2018_1 = sns_2018_1.drop('Unnamed: 0', axis=1)
sns_2018_2 = sns_2018_2.drop('Unnamed: 0', axis=1)
sns_2019_1 = sns_2019_1.drop('Unnamed: 0', axis=1)
sns_2019_2 = sns_2019_2.drop('Unnamed: 0', axis=1)

# 이후의 데이터 merge와 concat을 고려해 칼럼명 통일
buy_2018_1.columns = ['date','gender','age','big_cat','sm_cat','quantity']
buy_2018_2.columns = ['date','gender','age','big_cat','sm_cat','quantity']
buy_2019_1.columns = ['date','gender','age','big_cat','sm_cat','quantity']
buy_2019_2.columns = ['date','gender','age','big_cat','sm_cat','quantity']
sns_2018_1.columns = ['date','big_cat','sm_cat','count']
sns_2018_2.columns = ['date','big_cat','sm_cat','count']
sns_2019_1.columns = ['date','big_cat','sm_cat','count']
sns_2019_2.columns = ['date','big_cat','sm_cat','count']

# 데이터 합치기
# 연도별 구분 데이터셋
buy_2018 = pd.concat([buy_2018_1,buy_2018_2], ignore_index=True)      # 2018년의 구매데이터
buy_2019 = pd.concat([buy_2019_1,buy_2019_2], ignore_index=True)      # 2019년의 구매데이터
sns_2018 = pd.concat([sns_2018_1,sns_2018_2], ignore_index=True)      # 2018년의 SNS 노출 데이터
sns_2019 = pd.concat([sns_2019_1,sns_2019_2], ignore_index=True)      # 2019년의 SNS 노출 데이터
# 연도 구분 없는 총 데이터셋
buy = pd.concat([buy_2018,buy_2019], ignore_index=True)
sns = pd.concat([sns_2018,sns_2019], ignore_index=True)
# 뷰티, 식품, 냉난방가전 분류에 따라 분류된 buy, sns 총 데이터셋
buy_beauty = buy[buy['big_cat']== '뷰티'].reset_index(drop=True)
buy_food = buy[buy['big_cat']== '식품'].reset_index(drop=True)
buy_appliance = buy[buy['big_cat']== '냉난방가전'].reset_index(drop=True)
sns_beauty = sns[sns['big_cat']== '뷰티'].reset_index(drop=True)
sns_food = sns[sns['big_cat']== '식품'].reset_index(drop=True)
sns_appliance = sns[sns['big_cat']== '냉난방가전'].reset_index(drop=True)

#data열의 데이터 타입을 int ->  datatime 객체로 바꾸기
buy['date'] = pd.to_datetime(buy['date'].astype(str))
sns['date'] = pd.to_datetime(sns['date'].astype(str))

# 뷰티, 식품, 냉난방가전 분류에 따라 분류된 buy, sns 총 데이터셋
buy_beauty = buy[buy['big_cat']== '뷰티'].reset_index(drop=True)
buy_food = buy[buy['big_cat']== '식품'].reset_index(drop=True)
buy_appliance = buy[buy['big_cat']== '냉난방가전'].reset_index(drop=True)
sns_beauty = sns[sns['big_cat']== '뷰티'].reset_index(drop=True)
sns_food = sns[sns['big_cat']== '식품'].reset_index(drop=True)
sns_appliance = sns[sns['big_cat']== '냉난방가전'].reset_index(drop=True)

# %% [markdown]
# # Data Labeling
#
# ## 대분류 '뷰티'에 속하는 데이터의 세분화 라벨링
#
#
# ##### 식약처 화장품 정의 및 기준
# **기능성 화장품**,  **기초화장용 제품류**,  **색조화장용 제품류**,   **체모제거용 제품류**,  **방향용 제품류**  **손발톱용 제품류**, **면도용 제품류**,  **인체세정용 제품류**  ,**체취방지용 제품류**  ,**두발용 제품류**  ,**목욕용 제품류** ,**기타**, **두발염색용 제품류**

# %%
dict_beauty = {'기능성 링클케어 화장품':'기능성 화장품', '기능성 모공관리 화장품':'기능성 화장품', '기능성 아이케어 화장품':'기능성 화장품',
'기능성 영양보습 화장품':'기능성 화장품', '기능성 트러블케어 화장품':'기능성 화장품', '기능성 화이트닝 화장품':'기능성 화장품',
'기능성 화장품 세트':'기능성 화장품', '남성 선케어':'기능성 화장품', '선로션':'기능성 화장품', '선스프레이':'기능성 화장품', '선케어용 선밤':'기능성 화장품',
'선크림':'기능성 화장품', '선파우더':'기능성 화장품', '애프터선':'기능성 화장품', '태닝용 선크림':'기능성 화장품', 
'기초 화장용 로션':'기초화장용 제품류', '기초 화장용 미스트':'기초화장용 제품류', '기초 화장용 스킨':'기초화장용 제품류', '기초 화장용 에센스':'기초화장용 제품류', 
'기초 화장용 오일/앰플':'기초화장용 제품류', '기초 화장용 크림':'기초화장용 제품류', 
'남성 로션':'기초화장용 제품류', '남성 세트':'기초화장용 제품류', '남성 스킨':'기초화장용 제품류', '남성 에센스':'기초화장용 제품류', '남성 크림':'기초화장용 제품류',
'남성 클렌징':'기초화장용 제품류', '립앤아이 리무버':'기초화장용 제품류', '바디 보습제':'기초화장용 제품류', '바디 세트':'기초화장용 제품류', '바디케어용 볼륨업크림':'기초화장용 제품류',
'바디케어용 슬리밍':'기초화장용 제품류', '스킨케어 곡물팩':'기초화장용 제품류', '스킨케어 마스크팩':'기초화장용 제품류', '스킨케어 수면팩':'기초화장용 제품류',
'스킨케어 시트마스크팩':'기초화장용 제품류', '스킨케어 워시오프팩':'기초화장용 제품류', '스킨케어 코팩':'기초화장용 제품류', '스킨케어 필오프팩':'기초화장용 제품류',
'클렌징 로션':'기초화장용 제품류', '클렌징 오일':'기초화장용 제품류', '클렌징 워터/젤':'기초화장용 제품류', '클렌징 크림':'기초화장용 제품류', '클렌징 티슈':'기초화장용 제품류',
'클렌징 폼':'기초화장용 제품류', '팩도구':'기초화장용 제품류', '풋크림':'기초화장용 제품류', '핸드크림':'기초화장용 제품류', '화장 비누':'기초화장용 제품류',
'남성 메이크업':'색조화장용 제품류', '베이스 메이크업 세트':'색조화장용 제품류', '베이스 메이크업용 BB크림':'색조화장용 제품류', '베이스 메이크업용 CC크림':'색조화장용 제품류',
'베이스 메이크업용 가루파우더':'색조화장용 제품류', '베이스 메이크업용 메이크업베이스':'색조화장용 제품류', '베이스 메이크업용 컨실러':'색조화장용 제품류',
'베이스 메이크업용 쿠션팩트':'색조화장용 제품류', '베이스 메이크업용 트윈케이크':'색조화장용 제품류', '베이스 메이크업용 파우더팩트':'색조화장용 제품류',
'베이스 메이크업용 파운데이션':'색조화장용 제품류', '베이스 메이크업용 프라이머':'색조화장용 제품류', '색조 메이크업 립글로스':'색조화장용 제품류',
'색조 메이크업 립라이너':'색조화장용 제품류', '색조 메이크업 립밤':'색조화장용 제품류', '색조 메이크업 립스틱':'색조화장용 제품류', '색조 메이크업 립틴트':'색조화장용 제품류',
'색조 메이크업 마스카라':'색조화장용 제품류', '색조 메이크업 볼터치':'색조화장용 제품류', '색조 메이크업 세트':'색조화장용 제품류', '색조 메이크업 속눈썹영양제':'색조화장용 제품류',
'색조 메이크업 쉐딩/하이라이터':'색조화장용 제품류', '색조 메이크업 아이라이너':'색조화장용 제품류', '색조 메이크업 아이브로우':'색조화장용 제품류', '색조 메이크업 아이섀도우':'색조화장용 제품류',
'바디케어용 제모제':'체모제거용 제품류', '남성향수':'방향용 제품류', '샤워코롱':'방향용 제품류', '여성향수':'방향용 제품류', '향수세트':'방향용 제품류',
'네일 메이크업 용품':'손발톱용 제품류', '네일관리 소품':'손발톱용 제품류', '네일리무버':'손발톱용 제품류', '네일세트':'손발톱용 제품류', '네일아트':'손발톱용 제품류',
'네일컬러':'손발톱용 제품류', '네일케어':'손발톱용 제품류', '손톱정리도구':'손발톱용 제품류', '남성 쉐이빙':'면도용 제품류', '바디 스크럽':'인체세정용 제품류',
'바디 클렌져':'인체세정용 제품류', '바디케어용 때비누':'인체세정용 제품류', '바디케어용 청 결제':'인체세정용 제품류', '세안도구':'인체세정용 제품류', '스크럽/필링크림':'인체세정용 제품류',
'풋워시/스크럽':'인체세정용 제품류', '핸드워시/스크럽':'인체세정용 제품류',
'데오드란트':'체취방지용 제품류', '바디케어용 땀패드':'체취방지용 제품류', '풋스프레이':'체취방지용 제품류',
'린스':'두발용 제품류', '샴푸':'두발용 제품류', '트리트먼트':'두발용 제품류', '헤어무스':'두발용 제품류',
'헤어스타일링용 펌제':'두발용 제품류', '헤어스타일링용 흑채':'두발용 제품류', '헤어스프레이':'두발용 제품류',
'헤어에센스':'두발용 제품류', '헤어왁스':'두발용 제품류', '헤어젤':'두발용 제품류', '헤어케어세트':'두발용 제품류',
'헤어매니큐어':'두발염색용 제품류', '헤어스타일링용 염색약':'두발염색용 제품류', '입욕제':'목욕용 제품류',
'메이크업 박스': '기타', '메이크업 브러쉬': '기타', '미용가위': '기타', '뷰티 눈썹정리도구': '기타',
'뷰티 속눈썹/쌍꺼풀': '기타', '뷰티 손거울': '기타', '뷰티 타투': '기타', '뷰티 헤어캡': '기타', '뷰티 화장솜': '기타',
'뷰티 화장품 공병/케이스': '기타', '뷰티용 기름종이': '기타', '뷰티용 면봉/귀이개': '기타',
'뷰티용 뷰러': '기타', '뷰티용 샤프너': '기타', '뷰티용 여드름압출기': '기타', '풋패치': '기타', '헤어 브러쉬': '기타',
'화장 퍼프': '기타' 
}

# %%
buy_beauty['group'] = 'group'
buy_beauty['group'] = buy_beauty['sm_cat'].map(dict_beauty)
sns_beauty['group'] = 'group'
sns_beauty['group'] = sns_beauty['sm_cat'].map(dict_beauty)

# %%
buy_beauty['group'].unique()
# Out:
# array(['기능성 화장품', '기초화장용 제품류', '색조화장용 제품류', '면도용 제품류', '손발톱용 제품류',
#        '체취방지용 제품류', '두발용 제품류', '기타', '인체세정용 제품류', '체모제거용 제품류', '방향용 제품류',
#        '목욕용 제품류', '두발염색용 제품류'], dtype=object)

# %%
buy_beauty
# Out:
#              date gender  age big_cat        sm_cat  quantity    group
# 0      2018-01-01      F   20      뷰티  기능성 링클케어 화장품         2  기능성 화장품
# 1      2018-01-01      F   40      뷰티  기능성 링클케어 화장품         1  기능성 화장품
# 2      2018-01-01      F   20      뷰티  기능성 모공관리 화장품         7  기능성 화장품
# 3      2018-01-01      F   30      뷰티  기능성 모공관리 화장품         3  기능성 화장품
# 4      2018-01-01      F   40      뷰티  기능성 모공관리 화장품         1  기능성 화장품
# ...           ...    ...  ...     ...           ...       ...      ...
# 697848 2019-12-31      F   50      뷰티         화장 퍼프         7       기타
# 697849 2019-12-31      M   20      뷰티         화장 퍼프         9       기타
# 697850 2019-12-31      M   30      뷰티         화장 퍼프         4       기타
# 697851 2019-12-31      M   40      뷰티         화장 퍼프         3       기타
# 697852 2019-12-31      M   50      뷰티         화장 퍼프         5       기타
#
# [697853 rows x 7 columns]

# %% [markdown]
# ## 대분류 '식품' 에 속하는 데이터의 세분화 라벨링
# ##### 식품db 기준
# **곡류**,  **감자**,  **당류**,   **종실류**,  **채소류**  **버섯류**, **과실류**,  **육류**  ,**난류**  ,**어패류**  ,**해조류**  ,**우유류**
# ,**유지류**  ,**음료류**  ,**기타**
#
# ##### 뇌피셜로 나눈거
# **주식**, **건강_기타**, **건강_한방**, **건강_영양제**, **음료_카페**, **음료_기타**, **반찬_채소**, **반찬_기타**, **반찬_저장**, **과실류**, **육류**, **어패류**, **우유류**, **종실류**, **기타_건조**

# %%
buy_food1=buy_food
sns_food1=sns_food

# %%
## 식품db 기준
dict_food = {'쌀' : '곡류', '잡곡' : '곡류', '미숫가루/곡물가루' : '곡류', '혼합곡' : '곡류', '잡곡 씨드류' : '곡류',
             '반건조고구마' : '감자', '감자' : '감자',
             '카페용 초콜릿시럽' : '당류', '코코아/핫초코' : '당류',
             '견과류 땅콩' : '종실류', '견과류 캐슈넛' : '종실류', '견과류 호두' : '종실류', '혼합견과' : '종실류', '견과류 피스타치오' : '종실류', 
             '견과류 잣/은행' : '종실류', '견과류 카카오닙스' : '종실류', '견과류 밤' : '종실류', '견과류 마카다미아' : '종실류', '견과류' : '종실류',
             '배추김치' : '채소류', '기타 농산물' : '채소류', '반찬류' : '채소류', '백김치' : '채소류', '김치류' : '채소류', '갓김치' : '채소류', 
             '도라지/더덕' : '채소류', '무김치' : '채소류', '물김치' : '채소류', '파김치' : '채소류', '쌈채소' : '채소류', '마늘/생강' : '채소류', 
             '나물' : '채소류', '파/양파' : '채소류', '고추/피망/파프리카' : '채소류', '양배추/양상추' : '채소류', '미나리' : '채소류', '옥수수' : '채소류', 
             '믹스 채소' : '채소류', '호박' : '채소류', '브로콜리/셀러리' : '채소류', '어린잎/새싹채소' : '채소류', '절임배추/김치속' : '채소류', 
             '마/야콘' : '채소류', '오이/가지' : '채소류', '시금치' : '채소류', '우엉/연근' : '채소류', '무/배추' : '채소류', '콩나물/숙주' : '채소류', '부추' : '채소류',
             '표고버섯' : '버섯류', '상황버섯' : '버섯류', '영지버섯' : '버섯류', '새송이버섯' : '버섯류', '느타리버섯' : '버섯류',
             '과일세트' : '과실류', '건대추' : '과실류', '포도/거봉/체리' : '과실류', '곶감/반건시' : '과실류', '건바나나' : '과실류', '토마토' : '과실류', 
             '과일류' : '과실류', '딸기/복분자/블루베리' : '과실류', '건자두' : '과실류', '감귤/한라봉/오렌지' : '과실류', '건포도' : '과실류', '바나나/파인애플/망고' : '과실류', 
             '레몬/자몽' : '과실류', '건망고' : '과실류', '참외/메론/수박' : '과실류', '키위/참다래' : '과실류', '감말랭이' : '과실류', '감/홍시' : '과실류',
             '닭가슴살' : '육류', '국내산 돈육' : '육류', '구이/수육용 돈육' : '육류', '한우육' : '육류', '소고기 등심/안심' : '육류', '오리고기/훈제오리' : '육류', 
             '생닭/닭부분육' : '육류', '닭 양념육' : '육류', '양념 돈육' : '육류', '갈비/찜/바비큐용 돈육' : '육류', '장조림/카레용 돈육' : '육류', '수입우육' : '육류', 
             '양념우육' : '육류', '갈비용 우육' : '육류', '윙봉/닭다리/날개' : '육류', '돼지 곱창' : '육류', '소고기 육회' : '육류',
             '가공란' : '난류', '계란' : '난류', '메추리알' : '난류',
             '전복 생물' : '어패류', '젓갈류' : '어패류', '건어물 쥐포' : '어패류', '연어/훈제연어' : '어패류', '오징어' : '어패류', '건어물 황태' : '어패류', '고등어' : '어패류', 
             '굴비/조기' : '어패류', '건어물 마른오징어' : '어패류', '건어물 멸치' : '어패류', '주꾸미' : '어패류', '수산 생물' : '어패류', '조개' : '어패류', '건어물 진미채' : '어패류', 
             '생선류' : '어패류', '건어물 건새우' : '어패류', '랍스타' : '어패류', '새우/대하' : '어패류', '옥돔' : '어패류', '명태/동태' : '어패류', '낙지' : '어패류', '게장류' : '어패류', 
             '가자미' : '어패류', '문어' : '어패류', '건어물 노가리' : '어패류', '갈치' : '어패류', '홍어' : '어패류', '어란(생선알)' : '어패류', '굴 생물' : '어패류', '장어' : '어패류', 
             '삼치' : '어패류', '꽃게' : '어패류', '대게/킹크랩' : '어패류', '회' : '어패류',
             '해조류 미역' : '해조류', '해조류 다시마' : '해조류', '해초류 ' : '해조류',
             '흰우유' : '우유류', '딸기우유' : '우유류', '유제품 음료' : '우유류', '저/무지방우유' : '우유류', '초코우유' : '우유류', '요거트/발효유' : '우유류', '초유 영양제' : '우유류', 
             '바나나우유' : '우유류',
             '아몬드유/코코넛밀크' : '유지류', '커피용 프림' : '유지류',
             '탄산음료' : '음료류', '이온음료' : '음료류', '홍차' : '음료류', '커피음료' : '음료류', '과실차' : '음료류', '원두커피' : '음료류', '아이스티' : '음료류',
             '캡슐/POD커피' : '음료류', '식혜/수정과' : '음료류', '밀크티/티라떼' : '음료류', '허브차' : '음료류', '프라페/버블티 파우더' : '음료류', '탄산수' : '음료류', 
             '차 선물세트' : '음료류', '유자차' : '음료류', '기타 주스류' : '음료류', '음용 식초' : '음료류', '차/곡물 음료' : '음료류', '과채 음료/주스' : '음료류', '에이드' : '음료류', 
             '곡물차' : '음료류', '녹차' : '음료류', '야채/호박즙' : '음료류', '어린이 음료' : '음료류', '옥수수차' : '음료류', '인스턴트커피' : '음료류', '더치커피' : '음료류', 
             '홍삼 음료' : '음료류', '전통차' : '음료류', '율무차' : '음료류', '비타민/화이바 음료' : '음료류', '건강즙' : '음료류', '보리차' : '음료류', '전통주' : '음료류', 
             '둥굴레차' : '음료류', '생수' : '음료류', '두유' : '음료류', '옻/칡/쑥즙' : '음료류', '양파/마늘즙' : '음료류', '배/포도/과일즙' : '음료류', 
             '복분자/석류/과실즙' : '음료류', '숙취/에너지/건강 음료' : '음료류',
             '홍삼 분말/환' : '기타', '헛개/가시오가피' : '기타', '한방 분말/환제품' : '기타', '다이어트보조식' : '기타', '프로바이오틱스' : '기타', '환자식' : '기타', 
             '기타 한방/환제품' : '기타', '건강즙/녹용' : '기타', '콜라겐/코큐텐 영양제' : '기타', '한방재료' : '기타', '홍삼절편/홍삼정과' : '기타', '칼슘/철분 영양제' : '기타', 
             '비타민' : '기타', '홍삼/인삼 제품' : '기타', '선식' : '기타', '프로폴리스/로얄젤리' : '기타', '오메가3/스쿠알렌 영양제' : '기타', '홍삼액/홍삼정' : '기타', 
             '다이어트용 헬스보충식품' : '기타', '루테인/눈 영양제' : '기타', '어린이영양제' : '기타', '감마리놀렌산 영양제' : '기타', '홍삼 간식' : '기타', '어린이홍삼' : '기타', 
             '글루코사민/키토산 영양제' : '기타', '인삼/수삼/산삼' : '기타', '클로렐라 영양제' : '기타', '생식/선식 분말' : '기타', '과일채소 분말/분태' : '기타',
             '카페 푸드' : '기타', '스피루리나 영양제' : '기타'}

# %%
buy_food['group'] = 'group'
buy_food['group'] = buy_food['sm_cat'].map(dict_food)
sns_food['group'] = 'group'
sns_food['group'] = sns_food['sm_cat'].map(dict_food)

# %%
buy_food['group'].unique()
# Out:
# array(['난류', '어패류', '육류', '과실류', '기타', '감자', '채소류', '음료류', '종실류', '버섯류',
#        '우유류', '곡류', '유지류', '당류', '해조류'], dtype=object)

# %%
## 내 뇌피셜
dict_food1 = {'쌀' : '주식', '잡곡' : '주식', '혼합곡' : '주식', '잡곡 씨드류' : '주식',
              '환자식' : '건강_기타', '선식' : '건강_기타', '생식/선식 분말' : '건강_기타', '다이어트용 헬스보충식품' : '건강_기타', '다이어트보조식' : '건강_기타', 
              '숙취/에너지/건강 음료' : '건강_기타',
              '홍삼 분말/환' : '건강_한방', '헛개/가시오가피' : '건강_한방', '한방 분말/환제품' : '건강_한방', '기타 한방/환제품' : '건강_한방', '건강즙/녹용' : '건강_한방', 
              '한방재료' : '건강_한방',  '홍삼절편/홍삼정과' : '건강_한방', '홍삼/인삼 제품' : '건강_한방', '홍삼액/홍삼정' : '건강_한방', '홍삼 간식' : '건강_한방', 
              '홍삼 음료' : '건강_한방', '어린이홍삼' : '건강_한방', '건강즙' : '건강_한방', '옻/칡/쑥즙' : '건강_한방', '양파/마늘즙' : '건강_한방', '복분자/석류/과실즙' : '건강_한방', 
              '배/포도/과일즙' : '건강_한방', '야채/호박즙' : '건강_한방', '인삼/수삼/산삼' : '건강_한방',
              '스피루리나 영양제' : '건강_영양제', '프로바이오틱스' : '건강_영양제', '콜라겐/코큐텐 영양제' : '건강_영양제', '칼슘/철분 영양제' : '건강_영양제', '비타민' : '건강_영양제',   
              '프로폴리스/로얄젤리' : '건강_영양제', '오메가3/스쿠알렌 영양제' : '건강_영양제', '루테인/눈 영양제' : '건강_영양제', '어린이영양제' : '건강_영양제', 
              '감마리놀렌산 영양제' : '건강_영양제', '클로렐라 영양제' : '건강_영양제',  '글루코사민/키토산 영양제' : '건강_영양제',
              '커피음료' : '음료_카페', '원두커피' : '음료_카페', '캡슐/POD커피' : '음료_카페', '밀크티/티라떼' : '음료_카페', '카페용 초콜릿시럽' : '음료_카페', 
              '프라페/버블티 파우더' : '음료_카페', '인스턴트커피' : '음료_카페', '더치커피' : '음료_카페', '홍차' : '음료_카페',  '과실차' : '음료_카페', '허브차' : '음료_카페', 
              '차 선물세트' : '음료_카페', '차/곡물 음료' : '음료_카페', '코코아/핫초코' : '음료_카페', '녹차' : '음료_카페', '곡물차' : '음료_카페', '전통차' : '음료_카페', 
              '율무차' : '음료_카페', '카페 푸드' : '음료_카페',
              '탄산음료' : '음료_기타', '이온음료' : '음료_기타', '아이스티' : '음료_기타', '식혜/수정과' : '음료_기타', '미숫가루/곡물가루' : '음료_기타', '탄산수' : '음료_기타', 
              '유자차' : '음료_기타', '기타 주스류' : '음료_기타', '음용 식초' : '음료_기타', '과채 음료/주스' : '음료_기타', '에이드' : '음료_기타', '어린이 음료' : '음료_기타', 
              '생수' : '음료_기타', '옥수수차' : '음료_기타', '비타민/화이바 음료' : '음료_기타', '전통주' : '음료_기타', '둥굴레차' : '음료_기타', '보리차' : '음료_기타',
              '두유' : '음료_기타',
              '기타 농산물' : '반찬_채소', '도라지/더덕' : '반찬_채소', '감자' : '반찬_채소', '표고버섯' : '반찬_채소', '쌈채소' : '반찬_채소', '마늘/생강' : '반찬_채소', 
              '나물' : '반찬_채소', '파/양파' : '반찬_채소', '상황버섯' : '반찬_채소', '고추/피망/파프리카' : '반찬_채소', '양배추/양상추' : '반찬_채소', '미나리' : '반찬_채소', 
              '영지버섯' : '반찬_채소', '믹스 채소' : '반찬_채소', '호박' : '반찬_채소', '새송이버섯' : '반찬_채소', '브로콜리/셀러리' : '반찬_채소', '어린잎/새싹채소' : '반찬_채소', 
              '마/야콘' : '반찬_채소', '오이/가지' : '반찬_채소', '시금치' : '반찬_채소', '우엉/연근' : '반찬_채소', '느타리버섯' : '반찬_채소', '무/배추' : '반찬_채소', 
              '콩나물/숙주' : '반찬_채소', '부추' : '반찬_채소',
              '반찬류' : '반찬_기타', '해조류 다시마' : '반찬_기타', '해조류 미역' : '반찬_기타',  '해초류 ' : '반찬_기타', '가공란' : '반찬_기타', '계란' : '반찬_기타', '메추리알' : '반찬_기타',
              '배추김치' : '반찬_저장',   '백김치' : '반찬_저장', '김치류' : '반찬_저장', '갓김치' : '반찬_저장', '무김치' : '반찬_저장', '물김치' : '반찬_저장', '파김치' : '반찬_저장',  
              '절임배추/김치속' : '반찬_저장', '과일채소 분말/분태' : '반찬_저장', '젓갈류' : '반찬_저장', '건어물 황태' : '반찬_저장', '건어물 마른오징어' : '반찬_저장', 
              '건어물 멸치' : '반찬_저장', '건어물 진미채' : '반찬_저장', '건어물 건새우' : '반찬_저장', '게장류' : '반찬_저장',
              '과일세트' : '과실류', '포도/거봉/체리' : '과실류', '토마토' : '과실류', '과일류' : '과실류', '딸기/복분자/블루베리' : '과실류', '감귤/한라봉/오렌지' : '과실류',
              '바나나/파인애플/망고' : '과실류', '레몬/자몽' : '과실류', '참외/메론/수박' : '과실류', '키위/참다래' : '과실류', '감/홍시' : '과실류', '옥수수' : '과실류',
              '닭가슴살' : '육류', '국내산 돈육' : '육류', '구이/수육용 돈육' : '육류', '한우육' : '육류', '소고기 등심/안심' : '육류', '오리고기/훈제오리' : '육류',
              '생닭/닭부분육' : '육류', '닭 양념육' : '육류', '양념 돈육' : '육류', '갈비/찜/바비큐용 돈육' : '육류', '장조림/카레용 돈육' : '육류', '수입우육' : '육류',
              '양념우육' : '육류', '갈비용 우육' : '육류', '윙봉/닭다리/날개' : '육류', '돼지 곱창' : '육류', '소고기 육회' : '육류',
              '전복 생물' : '어패류', '연어/훈제연어' : '어패류', '오징어' : '어패류',  '고등어' : '어패류',  '굴비/조기' : '어패류',  '주꾸미' : '어패류', '수산 생물' : '어패류',
              '조개' : '어패류', '생선류' : '어패류', '랍스타' : '어패류', '새우/대하' : '어패류', '옥돔' : '어패류', '명태/동태' : '어패류', '낙지' : '어패류',
              '가자미' : '어패류', '문어' : '어패류', '갈치' : '어패류', '홍어' : '어패류', '어란(생선알)' : '어패류', '굴 생물' : '어패류', '장어' : '어패류',
              '삼치' : '어패류', '꽃게' : '어패류', '대게/킹크랩' : '어패류', '회' : '어패류',
              '흰우유' : '우유류', '딸기우유' : '우유류', '유제품 음료' : '우유류', '저/무지방우유' : '우유류', '초코우유' : '우유류', '요거트/발효유' : '우유류', '초유 영양제' : '우유류',
              '바나나우유' : '우유류', '아몬드유/코코넛밀크' : '우유류', '커피용 프림' : '우유류',
              '견과류 땅콩' : '종실류', '견과류 캐슈넛' : '종실류', '견과류 호두' : '종실류', '혼합견과' : '종실류', '견과류 피스타치오' : '종실류', 
              '견과류 잣/은행' : '종실류', '견과류 카카오닙스' : '종실류', '견과류 밤' : '종실류', '견과류 마카다미아' : '종실류', '견과류' : '종실류', 
              '반건조고구마' : '기타_건조', '건대추' : '기타_건조',  '곶감/반건시' : '기타_건조', '건바나나' : '기타_건조', '건자두' : '기타_건조',  '건포도' : '기타_건조', 
              '건망고' : '기타_건조',  '감말랭이' : '기타_건조', '건어물 노가리' : '기타_건조', '건어물 쥐포' : '기타_건조'
             }

# %%
buy_food1['group'] = 'group'
buy_food1['group'] = buy_food1['sm_cat'].map(dict_food1)
sns_food1['group'] = 'group'
sns_food1['group'] = sns_food1['sm_cat'].map(dict_food1)

# %%
buy_food1['group'].unique()
# Out:
# array(['반찬_기타', '어패류', '육류', '과실류', '건강_영양제', '기타_건조', '반찬_채소', '반찬_저장',
#        '건강_한방', '종실류', '음료_카페', '음료_기타', '건강_기타', '우유류', '주식'],
#       dtype=object)

# %% [markdown]
# ## 대분류 '냉난방가전'에 속하는 데이터의 세분화 라벨링
#
# **<냉방기>**
# 1) `에어컨` : 이동형 에어컨,멀티형 에어컨,스탠드형 에어컨,벽걸이 에어컨,냉풍기,중대형 에어컨,천장형 에어컨,에어컨 리모컨 상품에 해당
#
# 2) `선풍기` : 업소용 선풍기,탁상/USB 선풍기,휴대용 선풍기,벽걸이형 선풍기 상품에 해당
#
#
# **<난방기>**
# 1) `보일러` : 보일러,온수매트,전기장판,카페트매트,온열매트,황토매트 상품에 해당
#
# 2) `온수기` : 가스온수기,전기온수기 상품에 해당
#
# 3) `열풍기` : 온풍기,히터,돈풍기,라디에이터,난방용 열풍기,컨벡터 상품에 해당
#
#
# **<냉난방기>**
# 1) `냉난방기` : 스탠드형 냉온풍기,벽걸이형 냉온풍기 상품에 해당
#
# **<가습기>**
# 1) `가습기` : 초음파식 가습기,자연식 가습기,가열식 가습기,복합식 가습기 상품에 해당
#
# **<제습기>**
# 1) `제습기` : 제습기 상품에 해당
#
# **<공기청정기>**
# 1) `공기청정기` : 공기청정기,공기정화 용품,에어워셔,에어커튼,산림욕기 상품에 해당
#
# **<건조기>**
# 1) `건조기` : 신발건조기,의류건조기 상품에 해당

# %%
dict_appliance = {'이동형 에어컨' : '에어컨','멀티형 에어컨' :'에어컨','스탠드형 에어컨' : '에어컨','벽걸이 에어컨' : '에어컨',
                  '냉풍기' : '에어컨','중대형 에어컨' : '에어컨','천장형 에어컨' : '에어컨','에어컨 리모컨' : '에어컨',
                  '업소용 선풍기' : '선풍기','탁상/USB 선풍기' : '선풍기','휴대용 선풍기' : '선풍기','벽걸이형 선풍기': '선풍기',
                  '보일러' : '보일러','온수매트' : '보일러','전기장판' : '보일러','카페트매트' : '보일러',
                  '온열매트' : '보일러','황토매트' : '보일러',
                  '가스온수기' : '온수기' ,'전기온수기' : '온수기',
                  '온풍기' : '열풍기','히터' : '열풍기','돈풍기' : '열풍기','라디에이터' : '열풍기',
                  '난방용 열풍기' : '열풍기','컨벡터' : '열풍기',
                  '스탠드형 냉온풍기' :'냉난방기','벽걸이형 냉온풍기':'냉난방기',
                  '초음파식 가습기' : '가습기','자연식 가습기' : '가습기','가열식 가습기' :'가습기','복합식 가습기':'가습기',
                  '제습기': '제습기', 
                  '공기청정기':'공기청정기','공기정화 용품':'공기청정기','에어워셔':'공기청정기',
                  '에어커튼':'공기청정기','산림욕기':'공기청정기',
                  '신발건조기':'건조기', '의류건조기':'건조기'}

# %%
buy_appliance['group'] = 'group'
buy_appliance['group'] = buy_appliance['sm_cat'].map(dict_appliance)
sns_appliance['group'] = 'group'
sns_appliance['group'] = sns_appliance['sm_cat'].map(dict_appliance)

# %% [markdown]
# # 전체 데이터프레임 구성

# %%
def get_total_quantity_or_count(data1, data2):
    sub = data1.groupby('group').sum()
    extra = data2.groupby('group').sum()
    extra.columns = list(range(len(extra.columns)))
    return extra.join(sub).fillna(0)

def make_DataFrame_Format(buy_appliance):
    data_column_name = list(set(buy_appliance['group']))
    buy_columns = list(map(lambda x: x + '_buy', data_column_name))
    sns_columns = list(map(lambda x: x + '_sns', data_column_name))
    col_name = ['date','gender','20s_buy','30s_buy','40s_buy','50s_buy','60s_buy'] + buy_columns + sns_columns
    return pd.DataFrame(columns = col_name)

# %%
def set_DataFrame(buy,sns):
    # 타임라인 확정
    buy_timeline = list(set(buy['date']))

    # 데이터 프레임 틀 제작
    df = make_DataFrame_Format(buy)

    for count in tqdm(range(len(buy_timeline))):
        time = buy_timeline[count]
        main_buy = buy[buy['date']==time]
        main_sns = sns[sns['date']==time]

        # 남성데이터
        main_man_buy = main_buy[main_buy['gender']=='M']
        # 여성데이터
        main_woman_buy = main_buy[main_buy['gender']=='F']

        # 성별, 나이에 따른 구매수량 합
        man_age = list(main_man_buy.groupby('age').sum()['quantity'])
        woman_age = list(main_woman_buy.groupby('age').sum()['quantity'])

        # 성별, 상품군에 따른 구매수량 합
        man_buy_group = get_total_quantity_or_count(main_man_buy,buy)
        woman_buy_group = get_total_quantity_or_count(main_woman_buy,buy)

        man_group_buy = list(man_buy_group['quantity'])
        woman_group_buy = list(woman_buy_group['quantity'])

        # 상품군에 따른 광고 노출 합
        group_sns = get_total_quantity_or_count(main_sns,sns)
        list_group_sns = list(group_sns['count'])

        list_man = [time,'M'] + man_age + man_group_buy + list_group_sns
        list_woman = [time,'F'] + woman_age + woman_group_buy + list_group_sns

        df.loc[count*2] = list_man
        df.loc[count*2 +1] = list_woman
    return df

# %%
# beuaty 항목에 대한 전체 완성된 데이터셋
beauty = set_DataFrame(buy_beauty,sns_beauty)
beauty
# Out:
# ...
#            date gender 20s_buy 30s_buy 40s_buy 50s_buy 60s_buy 체취방지용 제품류_buy  \
# 0    2019-04-11      M    1032    1903    1772     823     246           309
# 1    2019-04-11      F    4425    6314    4475    1680     379           938
# 2    2019-10-03      M     806    1362    1420     599     158           278
# 3    2019-10-03      F    2867    4597    4403    1823     426          1147
# 4    2018-10-25      M     852    1724    1414     555     204           256
# ...         ...    ...     ...     ...     ...     ...     ...           ...
# 1455 2019-01-27      F    3457    5031    4020    1497     290           992
# 1456 2018-02-04      M     879    1583    1243     534     133           164
# 1457 2018-02-04      F    4065    4926    3770    1455     233           562
# 1458 2019-06-03      M    1261    2410    2279     864     303           610
# 1459 2019-06-03      F    4880    8024    5515    2058     384          1592
#
# ...

# %%
# food 항목에 대한 전체 완성된 데이터셋
food = set_DataFrame(buy_food,sns_food)
food
# Out:
# ...
#            date gender 20s_buy 30s_buy 40s_buy 50s_buy 60s_buy 음료_기타_buy  \
# 0    2019-04-11      M    1737    4313    4540    2387     750       436
# 1    2019-04-11      F    4201    9717    8550    3787     995       699
# 2    2019-10-03      M    1553    3443    3428    1546     531       322
# 3    2019-10-03      F    3915    7363    7219    3589     845       630
# 4    2018-10-25      M    1259    3329    2960    1422     459       240
# ...         ...    ...     ...     ...     ...     ...     ...       ...
# 1455 2019-01-27      F    3789    8823    8351    4115    1030       489
# 1456 2018-02-04      M    1551    3838    3164    1647     544       214
# 1457 2018-02-04      F    3765    7598    6213    3023     702       478
# 1458 2019-06-03      M    1868    4935    5260    2595     846       566
# 1459 2019-06-03      F    4460   11005    9842    4107    1035      1053
#
#      종실류_buy 반찬_저장_buy  ...   음료_카페_sns   반찬_기타_sns      우유류_sns      과실류_sns  \
# ...

# %%
# appliance 항목에 대한 전체 완성된 데이터
appliance = set_DataFrame(buy_appliance,sns_appliance)
appliance
# Out:
# ...
#            date gender 20s_buy 30s_buy 40s_buy 50s_buy 60s_buy 보일러_buy  \
# 0    2019-04-11      M      41     210     234     114      43      38
# 1    2019-04-11      F      72     245     192     148      39      48
# 2    2019-10-03      M      32     108     112      48      22      33
# 3    2019-10-03      F      54     135     141      85      22      40
# 4    2018-10-25      M      73     296     313     135      36     142
# ...         ...    ...     ...     ...     ...     ...     ...     ...
# 1455 2019-01-27      F      78     212     162      77      24     162
# 1456 2018-02-04      M      32     176     151      71      28    84.0
# 1457 2018-02-04      F      89     324     233     100      12     136
# 1458 2019-06-03      M      71     323     381     191      79      18
# 1459 2019-06-03      F     136     358     285     170      46      23
#
#      선풍기_buy 온수기_buy  ...    보일러_sns   선풍기_sns     온수기_sns   제습기_sns  \
# ...
